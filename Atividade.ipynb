# %% [markdown]
# <a href="https://colab.research.google.com/github/BusinessAnalyticsHub/Bootcamp_3ed/blob/develop/Grupos%20Tarde/Grupo%203%20-%203DS%20Group/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Projeto Data Science - Grupo 3DS

# %% [markdown]
# Foram baixados primeiramente os arquivos de dados telemétricos das cidades de Encantado, Muçum e Santa Tereza, no período de 01/08/2023 a 31/10/2023.
# Para o município de Santa Tereza, foram baixados dados de 2 estações: Santa Tereza e Linha José Julio.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_Encantado = pd.read_csv('https://github.com/BusinessAnalyticsHub/Bootcamp_3ed/raw/refs/heads/develop/Grupos%20Tarde/Grupo%203%20-%203DS%20Group/86720000-ENCANTADO.csv', encoding='ISO-8859-1', delimiter=';')
df_Mucum = pd.read_csv('https://github.com/BusinessAnalyticsHub/Bootcamp_3ed/raw/764457ed7be1488d7316dc5b7d6b9eb57128f7b2/Grupos%20Tarde/Grupo%203%20-%203DS%20Group/86510000-MUCUM.csv', encoding='ISO-8859-1', delimiter=';')
df_Sta_Tereza = pd.read_csv('https://github.com/BusinessAnalyticsHub/Bootcamp_3ed/raw/764457ed7be1488d7316dc5b7d6b9eb57128f7b2/Grupos%20Tarde/Grupo%203%20-%203DS%20Group/86472600-SANTA%20TEREZA.csv', encoding='ISO-8859-1', delimiter=';')
df_Lin_JJ = pd.read_csv('https://github.com/BusinessAnalyticsHub/Bootcamp_3ed/raw/764457ed7be1488d7316dc5b7d6b9eb57128f7b2/Grupos%20Tarde/Grupo%203%20-%203DS%20Group/86472000-LINHA%20JOSE%20JULIO.csv', encoding='ISO-8859-1', delimiter=';')

# %%
df_Encantado.head()
# Out:
#          Data      Hora      Chuva (mm)        Nível (cm) Vazão (m3/s)  \
# 0  01/08/2023  02:30:00  0               228                     251.8
# 1  01/08/2023  02:45:00  0               228                     251.8
# 2  01/08/2023  03:00:00  0               228                     251.8
# 3  01/08/2023  03:15:00  0               227                     248.1
# 4  01/08/2023  03:30:00  0               227                     248.1
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_Encantado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6071 entries, 0 to 6070
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Data          6071 non-null   object
#  1   Hora          6071 non-null   object
#  2   Chuva (mm)    6071 non-null   object
#  3   Nível (cm)    6071 non-null   object
#  4   Vazão (m3/s)  3709 non-null   object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 284.7+ KB

# %%
df_Mucum.head()
# Out:
#          Data      Hora      Chuva (mm)        Nível (cm) Vazão (m3/s)  \
# 0  01/08/2023  00:00:00  0               208                     219.1
# 1  01/08/2023  00:15:00  0               208                     219.1
# 2  01/08/2023  00:30:00  0               208                     219.1
# 3  01/08/2023  00:45:00  0               207                     216.9
# 4  01/08/2023  01:00:00  0               207                     216.9
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_Mucum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Data          8049 non-null   object
#  1   Hora          8049 non-null   object
#  2   Chuva (mm)    8049 non-null   object
#  3   Nível (cm)    8049 non-null   object
#  4   Vazão (m3/s)  7701 non-null   object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 377.4+ KB

# %%
teste de alteração
# Out:
#   File "<ipython-input-13-542491140a7f>", line 1
#     teste de alteração
#           ^
# SyntaxError: invalid syntax
